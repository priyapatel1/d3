# %% [markdown]
# <a href="https://colab.research.google.com/github/priyapatel1/d3/blob/main/SCS_3253_Group_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %%
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
fires_df = pd.read_csv("/content/drive/MyDrive/ML_Group_Project/data/fires_df.csv")

# %% [markdown]
# /content/drive/MyDrive/ML_Group_Project/data/fires_df.csv
# /content/drive/MyDrive/ML_Group_Project/data/no_fires_df.csv

# %%
fires_df
# Out:
#         Unnamed: 0        cell  ID.x  elevation  ID.y         SR_B3  ID.x.1  \
# 0                1      2018.0    20          0    20  14378.076923      20
# 1                2      2019.0    20          0    20  14478.461538      20
# 2                3      2020.0    20          0    20  14550.717949      20
# 3                4      2021.0    20          0    20  14550.717949      20
# 4                5      2022.0    20          0    20  14636.820513      20
# ...            ...         ...   ...        ...   ...           ...     ...
# 466418      466419  21753785.0    12          0    12  19800.102564      12
# 466419      466420  21753786.0    12          0    12  19800.102564      12
# 466420      466421  21753787.0    12          0    12  19973.230769      12
# 466421      466422  21753788.0    12          0    12  20694.820513      12
# 466422      466423  21753789.0    12          0    12  20694.820513      12
#
# ...

# %%
fires_df.describe()
# Out:
#           Unnamed: 0          cell           ID.x  elevation           ID.y  \
# count  466423.000000  4.664230e+05  466423.000000   466423.0  466423.000000
# mean   233212.000000  8.830060e+06      45.856285        0.0      45.856285
# std    134644.866641  6.107345e+06      66.790397        0.0      66.790397
# min         1.000000  2.018000e+03      12.000000        0.0      12.000000
# 25%    116606.500000  5.731374e+06      24.000000        0.0      24.000000
# 50%    233212.000000  7.334886e+06      38.000000        0.0      38.000000
# 75%    349817.500000  9.409132e+06      38.000000        0.0      38.000000
# max    466423.000000  2.175379e+07     394.000000        0.0     394.000000
#
#                SR_B3         ID.x.1          NBR.x         ID.y.1  \
# count  466423.000000  466423.000000  466423.000000  466423.000000
# mean    21152.645166      45.856285       0.263016      45.856285
# std      2644.874453      66.790397       0.027149      66.790397
# ...

# %%
no_fires_df = pd.read_csv("/content/drive/MyDrive/data/no_fires_df.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-0570378881ac> in <cell line: 1>()
# ----> 1 no_fires_df = pd.read_csv("/content/drive/MyDrive/data/no_fires_df.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
